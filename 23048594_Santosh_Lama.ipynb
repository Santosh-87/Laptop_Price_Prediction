# %% [markdown]
# # LAPTOP PRICE PREDICTION USING MACHINE LEARNING
#
# This notebook aims to predict laptop prices using machine learning regression models.
# The workflow includes data preprocessing, feature engineering, model training, evaluation, and comparison of multiple algorithms.

# %% [markdown]
# ## IMPORTING REQUIRED LIBRARIES FOR OPERATIONS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## DATASET LOADING

# %%
df = pd.read_csv('huggingface_laptop_dataset.csv')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df.sample(5)
# Out:
#       laptop_ID  Company            Product   TypeName  Inches  \
# 1118       1133  Toshiba  Portege X30-D-10K  Ultrabook    13.3
# 344         350     Dell             XPS 13  Ultrabook    13.3
# 761         770     Dell      Latitude 7280  Ultrabook    12.5
# 817         826       HP      Chromebook 11    Netbook    11.6
# 614         621     Dell      Latitude 5580   Notebook    15.6
#
#        ScreenResolution                                   Cpu   Ram  \
# 1118  Full HD 1920x1080            Intel Core i7 7500U 2.7GHz  16GB
# 344   Full HD 1920x1080            Intel Core i7 8550U 1.8GHz   8GB
# 761   Full HD 1920x1080            Intel Core i7 7600U 2.8GHz  16GB
# 817            1366x768  Intel Celeron Dual Core N3060 1.6GHz   4GB
# 614            1366x768            Intel Core i5 7300U 2.6GHz   4GB
#
#                   Memory                     Gpu       OpSys  Weight  \
# 1118           512GB SSD   Intel HD Graphics 620  Windows 10  1.05kg
# 344            256GB SSD  Intel UHD Graphics 620  Windows 10   1.2kg
# 761            256GB SSD   Intel HD Graphics 620  Windows 10  1.18kg
# 817   16GB Flash Storage   Intel HD Graphics 400   Chrome OS  1.23kg
# 614            500GB HDD   Intel HD Graphics 620       Linux  1.93kg
#
#       Price_euros
# 1118       2226.0
# 344        1579.0
# 761        1859.0
# 817         385.0
# 614         869.0

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.size
# Out:
# 16939

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.drop(columns='laptop_ID', inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %% [markdown]
# ## Converting Text Data of RAM and Weight to Numerical Format for further operations

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float64')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69
# 1        Intel HD Graphics 6000  macOS    1.34       898.94
# 2         Intel HD Graphics 620  No OS    1.86       575.00
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float64
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(3), int32(1), object(8)
# memory usage: 117.2+ KB

# %%
sns.distplot(df['Price_euros'])
# Out:
# C:\Users\lamab\AppData\Local\Temp\ipykernel_2860\2073861339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price_euros'])
# <Axes: xlabel='Price_euros', ylabel='Density'>

# %% [markdown]
# ## PRICE CONVERSION (Euro --> NPR)

# %%
Euro_to_NPR = 169.02

# %%
df['Price_NPR'] = (df['Price_euros'] * Euro_to_NPR).round(2)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  Price_NPR
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69  226434.40
# 1        Intel HD Graphics 6000  macOS    1.34       898.94  151938.84
# 2         Intel HD Graphics 620  No OS    1.86       575.00   97186.50
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45  428879.80
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60  304844.47

# %%
df.drop(columns='Price_euros', inplace=True)

# %%
sns.distplot(df['Price_NPR'])
# Out:
# C:\Users\lamab\AppData\Local\Temp\ipykernel_2860\4020296647.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price_NPR'])
# <Axes: xlabel='Price_NPR', ylabel='Density'>

# %%
df['Price_NPR'].describe()
# Out:
# count    1.303000e+03
# mean     1.899256e+05
# std      1.181465e+05
# min      2.940948e+04
# 25%      1.012430e+05
# 50%      1.651325e+05
# 75%      2.514815e+05
# max      1.030853e+06
# Name: Price_NPR, dtype: float64

# %%
sns.histplot(df['Price_NPR'], bins=30, kde=True)
plt.xlabel("Laptop Price (NPR)")
plt.title("Distribution of Laptop Prices in Nepali Rupees")
plt.show()

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'], y=df['Price_NPR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price_NPR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\lamab\AppData\Local\Temp\ipykernel_2860\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price_NPR'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price_NPR'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_NPR  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37  226434.40            0
# 1        Intel HD Graphics 6000  macOS    1.34  151938.84            0
# 2         Intel HD Graphics 620  No OS    1.86   97186.50            0
# 3            AMD Radeon Pro 455  macOS    1.83  428879.80            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37  304844.47            0

# %%
df.sample(5)
# Out:
#      Company                              Product   TypeName  Inches  \
# 541     Dell                          Vostro 5468   Notebook    14.0
# 384     Asus                         Zenbook Flip  Ultrabook    13.3
# 822   Lenovo                          Thinkpad X1  Ultrabook    14.0
# 664      MSI                       GP72VR Leopard     Gaming    17.3
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook    15.6
#
#                      ScreenResolution                                   Cpu  \
# 541                 Full HD 1920x1080              Intel Core i3 6006U 2GHz
# 384   Full HD / Touchscreen 1920x1080            Intel Core i7 7500U 2.7GHz
# 822       IPS Panel Full HD 1920x1080            Intel Core i7 7500U 2.7GHz
# 664                 Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz
# 1274                         1366x768  Intel Celeron Dual Core N3050 1.6GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 541     4             128GB SSD    Intel HD Graphics 520  Windows 10    1.60
# 384    16             512GB SSD    Intel HD Graphics 620  Windows 10    1.10
# 822     8             512GB SSD    Intel HD Graphics 620  Windows 10    1.13
# 664     8  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10    2.70
# 1274    4             500GB HDD        Intel HD Graphics  Windows 10    2.20
#
#       Price_NPR  Touchscreen
# 541   124376.75            0
# 384   295599.08            1
# 822   422380.98            0
# 664   251293.87            0
# 1274   62368.38            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price_NPR'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price_NPR'>

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#     Company               Product  TypeName  Inches  \
# 396  Lenovo         ThinkPad E580  Notebook    15.6
# 986      HP           Probook 450  Notebook    15.6
# 507    Acer  Aspire A515-51G-59QF  Notebook    15.6
# 279  Lenovo    IdeaPad 320-17IKBR  Notebook    17.3
# 805      HP         EliteBook 820   Netbook    12.5
#
#                 ScreenResolution                         Cpu  Ram     Memory  \
# 396  IPS Panel Full HD 1920x1080  Intel Core i7 8550U 1.8GHz    8  256GB SSD
# 986            Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8    1TB HDD
# 507  IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz    4    1TB HDD
# 279            Full HD 1920x1080  Intel Core i7 8550U 1.8GHz    8    2TB HDD
# 805                     1366x768  Intel Core i5 7300U 2.6GHz    8  256GB SSD
#
#                        Gpu       OpSys  Weight  Price_NPR  Touchscreen  Ips
# 396      AMD Radeon RX 550  Windows 10    2.10  207820.23            0    1
# 986  Intel HD Graphics 620  Windows 10    2.04  136230.12            0    0
# 507   Nvidia GeForce MX150  Windows 10    2.20  103609.26            0    1
# 279   Nvidia GeForce MX150       No OS    2.80  143497.98            0    0
# 805  Intel HD Graphics 620  Windows 10    1.26  234768.78            0    0

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price_NPR'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price_NPR'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
new_screenresolution=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
new_screenresolution.head()
# Out:
#                                0     1
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df['X_resolution']=new_screenresolution[0]

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_NPR  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  226434.40            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  151938.84            0    0
# 2         Intel HD Graphics 620  No OS    1.86   97186.50            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  428879.80            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  304844.47            0    1
#
#                     X_resolution
# 0  IPS Panel Retina Display 2560
# 1                           1440
# 2                   Full HD 1920
# 3  IPS Panel Retina Display 2880
# 4  IPS Panel Retina Display 2560

# %%
df['Y_resolution']=new_screenresolution[1]

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_NPR  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  226434.40            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  151938.84            0    0
# 2         Intel HD Graphics 620  No OS    1.86   97186.50            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  428879.80            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  304844.47            0    1
#
#                     X_resolution Y_resolution
# 0  IPS Panel Retina Display 2560         1600
# 1                           1440          900
# 2                   Full HD 1920         1080
# 3  IPS Panel Retina Display 2880         1800
# 4  IPS Panel Retina Display 2560         1600

# %%
df.sample(5)
# Out:
#     Company        Product  TypeName  Inches   ScreenResolution  \
# 764    Dell  Latitude 3380  Notebook    13.3           1366x768
# 466    Acer       Aspire 5  Notebook    15.6           1366x768
# 96     Dell  Inspiron 3567  Notebook    15.6  Full HD 1920x1080
# 620      HP    ProBook 650  Notebook    14.0           1366x768
# 52       HP         255 G6  Notebook    15.6  Full HD 1920x1080
#
#                             Cpu  Ram     Memory                       Gpu  \
# 764    Intel Core i3 6006U 2GHz    4  500GB HDD     Intel HD Graphics 520
# 466    Intel Core i3 6006U 2GHz    4  500GB HDD  Nvidia GeForce GTX 940MX
# 96   Intel Core i7 7500U 2.7GHz    8    1TB HDD        AMD Radeon R5 M430
# 620  Intel Core i5 7300U 2.6GHz    8  256GB SSD     Intel HD Graphics 620
# 52    AMD A6-Series 9220 2.5GHz    4  256GB SSD    AMD Radeon R4 Graphics
#
#           OpSys  Weight  Price_NPR  Touchscreen  Ips  X_resolution  \
# 764  Windows 10    1.65  143497.98            0    0          1366
# 466  Windows 10    2.20   79270.38            0    0          1366
# 96        Linux    2.20  101395.10            0    0  Full HD 1920
# 620  Windows 10    2.31  189978.48            0    0          1366
# 52   Windows 10    1.86   67352.78            0    0  Full HD 1920
#
#     Y_resolution
# 764          768
# 466          768
# 96          1080
# 620          768
# 52          1080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float64
#  11  Price_NPR         1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  Ips               1303 non-null   int64
#  14  X_resolution      1303 non-null   object
#  15  Y_resolution      1303 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(10)
# memory usage: 157.9+ KB

# %%
df['X_resolution'] = df['X_resolution'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_NPR  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  226434.40            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  151938.84            0    0
# 2         Intel HD Graphics 620  No OS    1.86   97186.50            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  428879.80            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  304844.47            0    1
#
#   X_resolution Y_resolution
# 0         2560         1600
# 1         1440          900
# 2         1920         1080
# 3         2880         1800
# 4         2560         1600

# %%
df['X_resolution']=df['X_resolution'].astype('int32')
df['Y_resolution']=df['Y_resolution'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float64
#  11  Price_NPR         1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  Ips               1303 non-null   int64
#  14  X_resolution      1303 non-null   int32
#  15  Y_resolution      1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(8)
# memory usage: 147.7+ KB

# %%
df.corr(numeric_only=True)['Price_NPR']
# Out:
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# Price_NPR       1.000000
# Touchscreen     0.191226
# Ips             0.252208
# X_resolution    0.556529
# Y_resolution    0.552809
# Name: Price_NPR, dtype: float64

# %%
df['Pixels_Per_Inch(PPI)'] = (((df['X_resolution']**2) + (df['Y_resolution']**2))**0.5 / df['Inches']).astype('float')

# %%
df.corr(numeric_only=True)['Price_NPR']
# Out:
# Inches                  0.068197
# Ram                     0.743007
# Weight                  0.210370
# Price_NPR               1.000000
# Touchscreen             0.191226
# Ips                     0.252208
# X_resolution            0.556529
# Y_resolution            0.552809
# Pixels_Per_Inch(PPI)    0.473487
# Name: Price_NPR, dtype: float64

# %%
df.drop(columns=['ScreenResolution','Inches','X_resolution','Y_resolution'], inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_NPR  Touchscreen  Ips  Pixels_Per_Inch(PPI)
# 0  226434.40            0    1            226.983005
# 1  151938.84            0    0            127.677940
# 2   97186.50            0    0            141.211998
# 3  428879.80            0    1            220.534624
# 4  304844.47            0    1            226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu_Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_NPR  Touchscreen  Ips  Pixels_Per_Inch(PPI)       Cpu_Name
# 0  226434.40            0    1            226.983005  Intel Core i5
# 1  151938.84            0    0            127.677940  Intel Core i5
# 2   97186.50            0    0            141.211998  Intel Core i5
# 3  428879.80            0    1            220.534624  Intel Core i7
# 4  304844.47            0    1            226.983005  Intel Core i5

# %%
df['Cpu_Name'].value_counts()
# Out:
# Cpu_Name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# AMD A9-Series 9410            3
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# AMD A6-Series A6-9220         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1505M           2
# Intel Xeon E3-1535M           2
# Intel Atom X5-Z8350           2
# Intel Atom x5-Z8300           1
# AMD E-Series 6110             1
# AMD E-Series 9000e            1
# AMD E-Series E2-6110          1
# AMD FX 9830P                  1
# AMD Ryzen 1600                1
# Intel Atom Z8350              1
# AMD A6-Series 7310            1
# AMD E-Series E2-9000          1
# AMD A12-Series 9700P          1
# AMD FX 8800P                  1
# AMD A4-Series 7210            1
# Samsung Cortex A72&A53        1
# AMD E-Series 9000             1
# Name: count, dtype: int64

# %%
def fetch_processor(text):
    if text == 'Intel Core i3' or text == 'Intel Core i5' or text == 'Intel Core i7':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_brand'] = df['Cpu_Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_NPR  Touchscreen  Ips  Pixels_Per_Inch(PPI)       Cpu_Name  \
# 0  226434.40            0    1            226.983005  Intel Core i5
# 1  151938.84            0    0            127.677940  Intel Core i5
# 2   97186.50            0    0            141.211998  Intel Core i5
# 3  428879.80            0    1            220.534624  Intel Core i7
# 4  304844.47            0    1            226.983005  Intel Core i5
#
#        Cpu_brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# 4  Intel Core i5

# %%
df['Cpu_brand'].value_counts()
# Out:
# Cpu_brand
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: count, dtype: int64

# %%
df['Cpu_brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu_brand'>

# %%
sns.barplot(x=df['Cpu_brand'],y=df['Price_NPR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_NPR  Touchscreen  Ips  Pixels_Per_Inch(PPI)       Cpu_Name  \
# 0  226434.40            0    1            226.983005  Intel Core i5
# 1  151938.84            0    0            127.677940  Intel Core i5
# 2   97186.50            0    0            141.211998  Intel Core i5
# 3  428879.80            0    1            220.534624  Intel Core i7
# 4  304844.47            0    1            226.983005  Intel Core i5
#
#        Cpu_brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# 4  Intel Core i5

# %%
df.drop(columns=['Cpu','Cpu_Name'], inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram               Memory  \
# 0   Apple  MacBook Pro  Ultrabook    8            128GB SSD
# 1   Apple  Macbook Air  Ultrabook    8  128GB Flash Storage
# 2      HP       250 G6   Notebook    8            256GB SSD
# 3   Apple  MacBook Pro  Ultrabook   16            512GB SSD
# 4   Apple  MacBook Pro  Ultrabook    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_NPR  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  226434.40            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  151938.84            0    0
# 2         Intel HD Graphics 620  No OS    1.86   97186.50            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  428879.80            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  304844.47            0    1
#
#    Pixels_Per_Inch(PPI)      Cpu_brand
# 0            226.983005  Intel Core i5
# 1            127.677940  Intel Core i5
# 2            141.211998  Intel Core i5
# 3            220.534624  Intel Core i7
# 4            226.983005  Intel Core i5

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 64GB SSD                           1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  256GB SSD             1
# 32GB HDD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# Fix 1: use raw string for regex
df['Memory'] = df['Memory'].astype(str).replace(r'\.0', '', regex=True)

df["Memory"] = df["Memory"].str.replace('GB', '', regex=False)
df["Memory"] = df["Memory"].str.replace('TB', '000', regex=False)

new = df["Memory"].str.split("+", n=1, expand=True)

df["first"] = new[0].str.strip()
df["second"] = new[1].fillna("0").str.strip()   # Fix 2: avoid inplace chaining

# Layer 1 flags
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash" in x else 0)

# Fix 3: SAFE numeric extraction (instead of str.replace + astype)
df["first"] = (
    df["first"]
    .str.extract(r'(\d+)', expand=False)
    .fillna(0)
    .astype(int)
)

# Layer 2 flags
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash" in x else 0)

# Fix 4: SAFE numeric extraction for second
df["second"] = (
    df["second"]
    .str.extract(r'(\d+)', expand=False)
    .fillna(0)
    .astype(int)
)

# Final storage columns
df["HDD"] = df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"]
df["SSD"] = df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"]
df["Hybrid"] = df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"]
df["Flash_Storage"] = df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"]

# Cleanup
df.drop(columns=[
    'Memory',
    'first', 'second',
    'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
    'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'
], inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_NPR  Touchscreen  Ips  Pixels_Per_Inch(PPI)      Cpu_brand  \
# 0    1.37  226434.40            0    1            226.983005  Intel Core i5
# 1    1.34  151938.84            0    0            127.677940  Intel Core i5
# 2    1.86   97186.50            0    0            141.211998  Intel Core i5
# 3    1.83  428879.80            0    1            220.534624  Intel Core i7
# 4    1.37  304844.47            0    1            226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage
# 0    0  128       0              0
# 1    0    0       0            128
# 2    0  256       0              0
# 3    0  512       0              0
# 4    0  256       0              0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_NPR  Touchscreen  Ips  Pixels_Per_Inch(PPI)      Cpu_brand  \
# 0    1.37  226434.40            0    1            226.983005  Intel Core i5
# 1    1.34  151938.84            0    0            127.677940  Intel Core i5
# 2    1.86   97186.50            0    0            141.211998  Intel Core i5
# 3    1.83  428879.80            0    1            220.534624  Intel Core i7
# 4    1.37  304844.47            0    1            226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage Gpu_brand
# 0    0  128       0              0     Intel
# 1    0    0       0            128     Intel
# 2    0  256       0              0     Intel
# 3    0  512       0              0       AMD
# 4    0  256       0              0     Intel

# %%
df['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu_brand'] != 'ARM']

# %%
df['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu_brand'],y=df['Price_NPR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram  OpSys  Weight  Price_NPR  Touchscreen  \
# 0   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  226434.40            0
# 1   Apple  Macbook Air  Ultrabook    8  macOS    1.34  151938.84            0
# 2      HP       250 G6   Notebook    8  No OS    1.86   97186.50            0
# 3   Apple  MacBook Pro  Ultrabook   16  macOS    1.83  428879.80            0
# 4   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  304844.47            0
#
#    Ips  Pixels_Per_Inch(PPI)      Cpu_brand  HDD  SSD  Hybrid  Flash_Storage  \
# 0    1            226.983005  Intel Core i5    0  128       0              0
# 1    0            127.677940  Intel Core i5    0    0       0            128
# 2    0            141.211998  Intel Core i5    0  256       0              0
# 3    1            220.534624  Intel Core i7    0  512       0              0
# 4    1            226.983005  Intel Core i5    0  256       0              0
#
#   Gpu_brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def clean_os(text):
    if text == 'Windows 10' or text == 'Windows 7' or text == 'Windows 10 S':
        return 'Windows'
    elif text == 'macOS' or text == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(clean_os)

# %%
df['os'].value_counts()
# Out:
# os
# Windows               1125
# Others/No OS/Linux     156
# Mac                     21
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram  OpSys  Weight  Price_NPR  Touchscreen  \
# 0   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  226434.40            0
# 1   Apple  Macbook Air  Ultrabook    8  macOS    1.34  151938.84            0
# 2      HP       250 G6   Notebook    8  No OS    1.86   97186.50            0
# 3   Apple  MacBook Pro  Ultrabook   16  macOS    1.83  428879.80            0
# 4   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  304844.47            0
#
#    Ips  Pixels_Per_Inch(PPI)      Cpu_brand  HDD  SSD  Hybrid  Flash_Storage  \
# 0    1            226.983005  Intel Core i5    0  128       0              0
# 1    0            127.677940  Intel Core i5    0    0       0            128
# 2    0            141.211998  Intel Core i5    0  256       0              0
# 3    1            220.534624  Intel Core i7    0  512       0              0
# 4    1            226.983005  Intel Core i5    0  256       0              0
#
#   Gpu_brand                  os
# 0     Intel                 Mac
# 1     Intel                 Mac
# 2     Intel  Others/No OS/Linux
# 3       AMD                 Mac
# 4     Intel                 Mac

# %%
df.drop(columns='OpSys', inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price_NPR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\lamab\AppData\Local\Temp\ipykernel_2860\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'], y=df['Price_NPR'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price_NPR'>

# %%
df.corr(numeric_only=True)['Price_NPR']
# Out:
# Ram                     0.742905
# Weight                  0.209867
# Price_NPR               1.000000
# Touchscreen             0.192917
# Ips                     0.253320
# Pixels_Per_Inch(PPI)    0.475368
# HDD                    -0.096891
# SSD                     0.670660
# Hybrid                  0.007942
# Flash_Storage          -0.040067
# Name: Price_NPR, dtype: float64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'], y=df['Price_NPR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.distplot(df['Price_NPR'])
# Out:
# C:\Users\lamab\AppData\Local\Temp\ipykernel_2860\4020296647.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price_NPR'])
# <Axes: xlabel='Price_NPR', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price_NPR']))
# Out:
# C:\Users\lamab\AppData\Local\Temp\ipykernel_2860\1293736784.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price_NPR']))
# <Axes: xlabel='Price_NPR', ylabel='Density'>

# %%
df.drop(columns='Product', inplace=True)

# %% [markdown]
# ## FEATURE AND TARGET SELECTION

# %%
X = df.drop(['Price_NPR'], axis=1)
y = np.log(df['Price_NPR'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37            0    1
# 1      Apple           Ultrabook    8    1.34            0    0
# 2         HP            Notebook    8    1.86            0    0
# 3      Apple           Ultrabook   16    1.83            0    1
# 4      Apple           Ultrabook    8    1.37            0    1
# ...      ...                 ...  ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1
# 1300  Lenovo            Notebook    2    1.50            0    0
# 1301      HP            Notebook    6    2.19            0    0
# 1302    Asus            Notebook    4    2.20            0    0
#
#       Pixels_Per_Inch(PPI)              Cpu_brand   HDD  SSD  Hybrid  \
# 0               226.983005          Intel Core i5     0  128       0
# 1               127.677940          Intel Core i5     0    0       0
# 2               141.211998          Intel Core i5     0  256       0
# 3               220.534624          Intel Core i7     0  512       0
# 4               226.983005          Intel Core i5     0  256       0
# ...                    ...                    ...   ...  ...     ...
# 1298            157.350512          Intel Core i7     0  128       0
# 1299            276.053530          Intel Core i7     0  512       0
# 1300            111.935204  Other Intel Processor     0    0       0
# 1301            100.454670          Intel Core i7  1000    0       0
# 1302            100.454670  Other Intel Processor   500    0       0
#
#       Flash_Storage Gpu_brand                  os
# 0                 0     Intel                 Mac
# 1               128     Intel                 Mac
# 2                 0     Intel  Others/No OS/Linux
# 3                 0       AMD                 Mac
# 4                 0     Intel                 Mac
# ...             ...       ...                 ...
# 1298              0     Intel             Windows
# 1299              0     Intel             Windows
# 1300             64     Intel             Windows
# 1301              0       AMD             Windows
# 1302              0     Intel             Windows
#
# [1302 rows x 14 columns]

# %%
y
# Out:
# 0       12.330211
# 1       11.931233
# 2       11.484387
# 3       12.968932
# 4       12.627557
#           ...
# 1298    11.588355
# 1299    12.442571
# 1300    10.563739
# 1301    11.768585
# 1302    11.040814
# Name: Price_NPR, Length: 1302, dtype: float64

# %% [markdown]
# ## TRAIN_TEST SPLIT TO DIVIDE THE DATA INTO TRAINING DATA AND TEST DATA

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips  \
# 147     Asus            Notebook    4    2.00            0    0
# 342       HP            Notebook    8    2.10            0    1
# 1003      HP            Notebook    4    1.64            0    0
# 814     Dell            Notebook    8    2.18            0    0
# 344     Dell           Ultrabook    8    1.20            0    0
# ...      ...                 ...  ...     ...          ...  ...
# 1095    Acer            Notebook    8    2.40            0    0
# 1130      HP            Notebook    8    2.04            0    0
# 1295    Dell            Notebook    8    2.30            0    0
# 860   Lenovo            Notebook    8    2.30            0    1
# 1126  Lenovo  2 in 1 Convertible    4    0.69            1    1
#
#       Pixels_Per_Inch(PPI)              Cpu_brand   HDD  SSD  Hybrid  \
# 147             141.211998  Other Intel Processor  1000    0       0
# 342             141.211998          Intel Core i3  1000    0       0
# 1003            111.935204          Intel Core i5   500    0       0
# 814             141.211998          Intel Core i5     0  256       0
# 344             165.632118          Intel Core i7     0  256       0
# ...                    ...                    ...   ...  ...     ...
# 1095            141.211998          Intel Core i5  1000  256       0
# 1130            100.454670          Intel Core i7  2000    0       0
# 1295            100.454670          Intel Core i7  1000    0       0
# 860             141.211998          Intel Core i5  1000    0       0
# 1126            224.173809  Other Intel Processor     0    0       0
#
#       Flash_Storage Gpu_brand                  os
# 147               0     Intel             Windows
# 342               0    Nvidia             Windows
# 1003              0     Intel             Windows
# 814               0       AMD             Windows
# 344               0     Intel             Windows
# ...             ...       ...                 ...
# 1095              0    Nvidia             Windows
# 1130              0     Intel             Windows
# 1295              0       AMD  Others/No OS/Linux
# 860               0     Intel             Windows
# 1126             64     Intel             Windows
#
# [1041 rows x 14 columns]

# %%
X_test
# Out:
#      Company  TypeName  Ram  Weight  Touchscreen  Ips  Pixels_Per_Inch(PPI)  \
# 478     Dell  Notebook    8    2.20            0    0            141.211998
# 724      MSI    Gaming    8    2.70            0    0            127.335675
# 312      MSI    Gaming   16    2.80            0    1            141.211998
# 851     Asus    Gaming   16    2.10            0    0            141.211998
# 1276    Dell  Notebook    6    2.30            0    0            100.454670
# ...      ...       ...  ...     ...          ...  ...                   ...
# 199       HP  Notebook    8    2.50            0    0            127.335675
# 296     Acer  Notebook    8    2.50            0    0            141.211998
# 286   Lenovo  Notebook    8    1.95            0    1            141.211998
# 997     Acer  Notebook    4    2.40            0    0            100.454670
# 10        HP  Notebook    4    1.86            0    0            100.454670
#
#                   Cpu_brand   HDD  SSD  Hybrid  Flash_Storage Gpu_brand  \
# 478           Intel Core i5  1000    0       0              0       AMD
# 724           Intel Core i7  1000  128       0              0    Nvidia
# 312           Intel Core i7  1000  256       0              0    Nvidia
# 851           Intel Core i7  1000  128       0              0    Nvidia
# 1276          Intel Core i3  1000    0       0              0     Intel
# ...                     ...   ...  ...     ...            ...       ...
# 199           Intel Core i7     0  256       0              0    Nvidia
# 296           Intel Core i7     0  256       0              0    Nvidia
# 286           Intel Core i7     0  256       0              0     Intel
# 997   Other Intel Processor   500    0       0              0     Intel
# 10            Intel Core i5   500    0       0              0     Intel
#
#                       os
# 478              Windows
# 724              Windows
# 312              Windows
# 851              Windows
# 1276             Windows
# ...                  ...
# 199              Windows
# 296   Others/No OS/Linux
# 286              Windows
# 997              Windows
# 10    Others/No OS/Linux
#
# [261 rows x 14 columns]

# %%
y_train
# Out:
# 147     10.970659
# 342     11.703697
# 1003    11.788028
# 814     11.801809
# 344     12.494564
#           ...
# 1095    11.813378
# 1130    11.574148
# 1295    11.822088
# 860     11.876030
# 1126    11.301718
# Name: Price_NPR, Length: 1041, dtype: float64

# %%
y_test
# Out:
# 478     11.644730
# 724     12.336750
# 312     12.779233
# 851     12.679100
# 1276    11.259067
#           ...
# 199     12.081789
# 296     12.016549
# 286     12.130352
# 997     11.070188
# 10      11.106114
# Name: Price_NPR, Length: 261, dtype: float64

# %% [markdown]
# ## SEPERATING CATEGORICAL AND NUMERICAL FEATURES

# %%
categorical_cols = [
    'Company',
    'TypeName',
    'Cpu_brand',
    'Gpu_brand',
    'os'
]

numerical_cols = [
    col for col in X.columns if col not in categorical_cols
]

# %%
categorical_cols
# Out:
# ['Company', 'TypeName', 'Cpu_brand', 'Gpu_brand', 'os']

# %%
numerical_cols
# Out:
# ['Ram',
#  'Weight',
#  'Touchscreen',
#  'Ips',
#  'Pixels_Per_Inch(PPI)',
#  'HDD',
#  'SSD',
#  'Hybrid',
#  'Flash_Storage']

# %% [markdown]
# ## ENCODING CATEGORICAL FEATURES USING COLUMNTRANSFORMER

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols)
    ],
    remainder='passthrough'
)

# %%
preprocessor
# Out:
# C:\Users\lamab\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('cat',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  ['Company', 'TypeName', 'Cpu_brand',
#                                   'Gpu_brand', 'os'])])

# %% [markdown]
# ## Building Machine Learning Pipelines
#
# To streamline preprocessing and model training:
# - Pipelines are used to combine preprocessing and model steps
# - This ensures that the same preprocessing is applied during both training and testing
# - Pipelines reduce data leakage and improve code organization
#
# Each regression model is trained using its own pipeline consisting of:
# 1. Data preprocessing
# 2. Model training

# %% [markdown]
# ### Linear Regression Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

lr_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LinearRegression())
])

# %%
lr_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Company', 'TypeName',
#                                                    'Cpu_brand', 'Gpu_brand',
#                                                    'os'])])),
#                 ('model', LinearRegression())])

# %% [markdown]
# ## Random Forest Pipeline

# %%
from sklearn.ensemble import RandomForestRegressor

rf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestRegressor(
        n_estimators=200,
        random_state=42,
        n_jobs=-1
    ))
])

# %%
rf_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Company', 'TypeName',
#                                                    'Cpu_brand', 'Gpu_brand',
#                                                    'os'])])),
#                 ('model',
#                  RandomForestRegressor(n_estimators=200, n_jobs=-1,
#                                        random_state=42))])

# %% [markdown]
# ## XGBoost Pipeline

# %%
from xgboost import XGBRegressor

xgb_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', XGBRegressor(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42
    ))
])

# %%
xgb_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Company', 'TypeName',
#                                                    'Cpu_brand', 'Gpu_brand',
#                                                    'os'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=0.8, device=None,
#                               ear...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.05,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=6, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=300, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
models = {
    'Linear Regression': lr_pipeline,
    'Random Forest': rf_pipeline,
    'XGBoost': xgb_pipeline
}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    results.append({
        'Model': name,
        'MAE': mean_absolute_error(y_test, preds),
        'RMSE': np.sqrt(mean_squared_error(y_test, preds)),
        'R2 Score': r2_score(y_test, preds)
    })

results_df = pd.DataFrame(results)

# %%
results
# Out:
# [{'Model': 'Linear Regression',
#   'MAE': 0.21444258119510878,
#   'RMSE': np.float64(0.27213704771638103),
#   'R2 Score': 0.8077866862204068},
#  {'Model': 'Random Forest',
#   'MAE': 0.165299037446128,
#   'RMSE': np.float64(0.21761911271467738),
#   'R2 Score': 0.8770857604745127},
#  {'Model': 'XGBoost',
#   'MAE': 0.15550542867171865,
#   'RMSE': np.float64(0.20723881267607314),
#   'R2 Score': 0.8885319717764798}]

# %% [markdown]
# ## LINEAR REGRESSION MODEL

# %%
results[0]
# Out:
# {'Model': 'Linear Regression',
#  'MAE': 0.21444258119510878,
#  'RMSE': np.float64(0.27213704771638103),
#  'R2 Score': 0.8077866862204068}

# %% [markdown]
# ## RANDOM FOREST REGRESSSION

# %%
results[1]
# Out:
# {'Model': 'Random Forest',
#  'MAE': 0.165299037446128,
#  'RMSE': np.float64(0.21761911271467738),
#  'R2 Score': 0.8770857604745127}

# %% [markdown]
# ## XGBOOST REGRESSION

# %%
results[2]
# Out:
# {'Model': 'XGBoost',
#  'MAE': 0.15550542867171865,
#  'RMSE': np.float64(0.20723881267607314),
#  'R2 Score': 0.8885319717764798}
